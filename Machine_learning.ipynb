# %% [markdown]
# <a href="https://colab.research.google.com/github/javier-albino/Javier_Sandoval_Prueba2/blob/master/Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Monto Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Especifico la ubicación de los archivos de Excel en Google Drive
excel_file1 = '/content/drive/MyDrive/carpeta1/Bd_Consolidado_Final_3_Años.xlsx'

# Cargo los datos desde un archivo Excel en drive

data = pd.read_excel(excel_file1)
df_interes = data 
# x_=df_interes.drop(['Cantidad de pedido'])
# y_=df_interes(['Cantidad de pedido'])

# print (x_)

# Selecciono las columnas de interés


# Entreno el modelo de regresión lineal
#model = LinearRegression()
#model.fit(x, y)

# Creo un nuevo registro de datos con los valores de "Material" y "Cantidad de pedido"
# y una "Fecha de entrega" desconocida
# new_data = pd.DataFrame({
    # "Material": ["ALIMENTUM"],
    # "Cantidad de pedido": [10],
   #  "Fecha de entrega": ["2022-12-30"]
# })

# Hago una predicción con el modelo de regresión lineal para el nuevo registro de datos
# prediction = model.predict(new_data)

# Agrego la predicción como una columna a los datos de entrada
# new_data["predicción"] = prediction

# Selecciono el registro con la mayor "Fecha de entrega" en función de la predicción
# max_date_row = new_data.loc[new_data["Fecha de entrega"] == new_data["Fecha de entrega"].max()]

# Imprimo el resultado
# print(max_date_row["Material"])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_interes= pd.DataFrame(df_interes)

# %%
df_interes
# Out:
#                        Proveedor/Centro suministrador Documento compras  \
# 0           92034293   COMERCIAL RESCATELIFE LIMITADA        4179598363
# 1             92033360   PLASTICOS WILLIAM HADDAD LTD        4660709823
# 2            92033240   HANNA INSTRUMENTS EQUIPOS LTD        4168503547
# 3          92033471   PROVEEDORES INTEGRALES PRISA SA        4232967489
# 4                                92105484   TRECK S A        4659130789
# ...                                               ...               ...
# 189372  92033847   SOCIEDAD DE INGENIERIA EN LIMPIEZA                EC
# 189373      92034293   COMERCIAL RESCATELIFE LIMITADA                EC
# 189374      92034293   COMERCIAL RESCATELIFE LIMITADA                EC
# 189375                           92105484   TRECK S A                EC
# 189376                           92105484   TRECK S A                EC
#
#           Posición Fecha documento                                  Material  \
# ...

# %%
x_=df_interes[['Proveedor/Centro suministrador','Documento compras','Posición','Fecha documento','Material','Texto breve','Fecha de entrega','Cantidad entrada','Por entregar (cantidad)','Centro','Cantidad base','Indicador de borrado','Valor neto de pedido','Grupo de artículos','MG','Planta']]
x_
y_=df_interes[['Cantidad de pedido']]

# %%
for column in df_interes:
  df_interes[column].replace({'CL70':70}, inplace=True)

# %%
 df_interes
# Out:
#                        Proveedor/Centro suministrador Documento compras  \
# 0           92034293   COMERCIAL RESCATELIFE LIMITADA        4179598363
# 1             92033360   PLASTICOS WILLIAM HADDAD LTD        4660709823
# 2            92033240   HANNA INSTRUMENTS EQUIPOS LTD        4168503547
# 3          92033471   PROVEEDORES INTEGRALES PRISA SA        4232967489
# 4                                92105484   TRECK S A        4659130789
# ...                                               ...               ...
# 189372  92033847   SOCIEDAD DE INGENIERIA EN LIMPIEZA                EC
# 189373      92034293   COMERCIAL RESCATELIFE LIMITADA                EC
# 189374      92034293   COMERCIAL RESCATELIFE LIMITADA                EC
# 189375                           92105484   TRECK S A                EC
# 189376                           92105484   TRECK S A                EC
#
#           Posición Fecha documento                                  Material  \
# ...

# %%
df_interes.value_counts()
# Out:
# Proveedor/Centro suministrador    Documento compras  Posición    Fecha documento  Material             Texto breve                         Cantidad de pedido  Fecha de entrega     Cantidad entrada  Por entregar (cantidad)  Centro  Cantidad base  Indicador de borrado  Valor neto de pedido  Grupo de artículos  MG             Planta        Unnamed: 17
# 92099049   DIFEM LABORATORIOS SA  EC                 4011311340  1                2022-06-23 00:00:00  CLORO HIPOCLORITO SODIO 5% ENV. 5L  14                  2022-07-01 00:00:00  0                 0                        CL38    12488.0        L                     97000000.0            8.0                 Trading goods  El olivar     Inventariable    1
# ...
